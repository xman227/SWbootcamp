# %% [markdown]
# <a href="https://colab.research.google.com/github/xman227/SWbootcamp/blob/main/%EB%B0%B1%EC%86%8C%EB%AF%B8/project2_pill_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 아직 방향성이 안잡히신 분들은 

# 데이터 전처리 이미지에서 bbox 좌표를 이용해서 다 crop해보기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from PIL import Image
import pandas as pd

import os
import json
import glob
import pandas as pd
import imageio
import matplotlib.pyplot as plt

# %%
#파일 압축해제
# %cd /content/drive/MyDrive/BootCamp/project2/data/label_data
# !unzip -qq "/content/drive/MyDrive/BootCamp/project2/data/label_data/VL_1.zip"
# Out:
# /content/drive/MyDrive/BootCamp/project2/data/label_data

# %%
# %cd /content/drive/MyDrive/BootCamp/project2/data/origin_data
# !unzip -qq "/content/drive/MyDrive/BootCamp/project2/data/origin_data/VS_1.zip"
# Out:
# /content/drive/MyDrive/BootCamp/project2/data/origin_data
# replace K-016235-027733-029667-031885/K-016235-027733-029667-031885_0_2_0_2_70_000_200.png? [y]es, [n]o, [A]ll, [N]one, [r]ename: A

# %%
import json
example_file = open('/content/drive/MyDrive/BootCamp/project2/data/label_data/K-016235-027733-029667-031885_json/K-016235/K-016235-027733-029667-031885_0_2_0_2_70_000_200.json')
json_file = json.load(example_file)

# %%
json_file.get('images')
# Out:
# [{'file_name': 'K-016235-027733-029667-031885_0_2_0_2_70_000_200.png',
#   'width': 976,
#   'height': 1280,
#   'imgfile': 'K-016235-027733-029667-031885_0_2_0_2_70_000_200.png',
#   'drug_N': 'K-016235',
#   'drug_S': '정상알약',
#   'back_color': '연회색 배경',
#   'drug_dir': '앞면',
#   'light_color': '주백색',
#   'camera_la': 70,
#   'camera_lo': 0,
#   'size': 200,
#   'dl_idx': '16234',
#   'dl_mapping_code': 'K-016235',
#   'dl_name': '카듀엣정 5mg/20mg',
#   'dl_name_en': 'Caduet Tab. 5mg/20mg',
#   'img_key': 'http://connectdi.com/design/img/drug/153002764366500052.jpg',
#   'dl_material': '아토르바스타틴칼슘삼수화물|암로디핀베실산염',
#   'dl_material_en': 'Amlodipine Besylate| Atorvastatin Calcium Trihydrate',
#   'dl_custom_shape': '정제, 저작정',
#   'dl_company': '한국화이자제약(주)',
#   'dl_company_en': 'Pfizer Korea',
#   'di_company_mf': 'Pfizer Manufacturing Deutschland GmbH',
#   'di_company_mf_en': '',
#   'item_seq': 200410088,
#   'di_item_permit_date': '20041123',
#   'di_class_no': '[02190]기타의 순환계용약',
# ...

# %%
import os
mother_path = '/content/drive/MyDrive/BootCamp/project2/data/label_data'
folder_list = os.listdir(mother_path)
for folder in folder_list:
    print(mother_path + folder)
# Out:
# /content/drive/MyDrive/BootCamp/project2/data/label_dataK-016262-027653-034597-038723_json
# /content/drive/MyDrive/BootCamp/project2/data/label_dataK-016262-027653-028763-038723_json
# /content/drive/MyDrive/BootCamp/project2/data/label_dataK-016262-027653-031885-038723_json
# /content/drive/MyDrive/BootCamp/project2/data/label_dataK-016262-027733-030308-038723_json
# /content/drive/MyDrive/BootCamp/project2/data/label_dataK-016262-025469-034597-038723_json
# /content/drive/MyDrive/BootCamp/project2/data/label_dataK-016262-027733-028763-038723_json
# /content/drive/MyDrive/BootCamp/project2/data/label_dataK-016262-027653-030308-038723_json
# /content/drive/MyDrive/BootCamp/project2/data/label_dataK-016262-027777-031885-038723_json
# /content/drive/MyDrive/BootCamp/project2/data/label_dataK-016262-027733-034597-038723_json
# /content/drive/MyDrive/BootCamp/project2/data/label_dataK-016262-027777-028763-038723_json
# ...
